# %% [markdown]
# ---
#
# # <center><b>LetsGrowMore- Data Science Intern</b></center>
# <font size=4><center>Author: Soundarya G</center></font>
#
# ---

# %% [markdown]
# ## <center>TASK 3: Image to Pencil Sketch with Python </center>

# %% [markdown]
# ### Table of contents
# <br>
# <div>
#   <ul>
#     <li><a href="#intro">Introduction</a></li>
#     <li><a href="#load">Importing necessary libraries</a></li>
#     <li><a href="#eda">Load the picture</a></li>
#     <li><a href="#pre-processing">Display image using OpenCV</a></li>
#     <li><a href="#model-building">Display using Matplotlib</a></li>
#     <li><a href="#results">Greyscale Image</a></li>
#     <li><a href="#conclusion">Invert Image</a></li>
#     <li><a href="#conclusion">Blur Image</a></li>
#     <li><a href="#conclusion">Invert Blur Image</a></li>
#     <li><a href="#conclusion">Sketch</a></li>
#     <li><a href="#conclusion">Conclusion</a></li>
#   </ul>
# </div>

# %% [markdown]
# <br><h2 id="intro">📌INTRODUCTION</h2>
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# <h2 id="intro">📌IMPORTING NECESSARY LIBRARIES</h2>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# <h2 id="intro">📌LOAD THE PICTURE</h2>

# %%
image = cv2.imread("/content/dog.jpg")

# %% [markdown]
# <h2 id="intro">📌DISPLAY IMAGE USING OpenCV</h2>

# %%
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=301x168 at 0x7EFD0FD84F50>

# %% [markdown]
# <h2 id="intro">📌DISPLAY IMAGE USING MATPLOTLIB</h2>

# %%
plt.imshow(image)
plt.axis(False)
plt.show()

# %% [markdown]
# <h2 id="intro">📌CONVERT TO GREYSCALE IMAGE</h2>

# %%
grey_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=301x168 at 0x7EFD10B24890>

# %% [markdown]
# <h2 id="intro">📌INVERT THE IMAGE</h2>

# %%
invert_image = cv2.bitwise_not(grey_img)
cv2_imshow(invert_image)
# Out:
# <PIL.Image.Image image mode=L size=301x168 at 0x7EFD0FD309D0>

# %% [markdown]
# <h2 id="intro">📌BLUR THE IMAGE</h2>

# %%
blur_img = cv2.GaussianBlur(invert_image,(111,111),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=301x168 at 0x7EFD0FD34590>

# %% [markdown]
# <h2 id="intro">📌INVERT THE BLUR IMAGE</h2>

# %%
invblur_img=cv2.bitwise_not(blur_img)
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=301x168 at 0x7EFD0FD34B50>

# %% [markdown]
# <h2 id="intro">📌SKETCH<h2>

# %%
sketch_img=cv2.divide(grey_img, invblur_img, scale=256.0)

# %%
cv2.imwrite("save.png",sketch_img)
# Out:
# True

# %% [markdown]
# **DISPLAY SKETCH**

# %%
cv2_imshow(sketch_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=301x168 at 0x7EFD0FD3B0D0>

# %% [markdown]
# <br><h2 id="intro">📌CONCLUSION</h2>
#
# The Dog image is converted into pencil sketch with cv2 library in python.

# %% [markdown]
# ---
#
# # <center><b>THANK YOU</b></center>
#
# ---
